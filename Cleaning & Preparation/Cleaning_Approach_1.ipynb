# %% [markdown]
# # Cleaning Approach 1
# This approach inlvoves a straightforward instance-level cleaning with a focus on filling missing values.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading Data

# %%
df_real = pd.read_csv('../Data/real_instances.csv')
df_sim = pd.read_csv('../Data/simulated_instances.csv')
df_drawn = pd.read_csv('../Data/hand_drawn_instances.csv')

#combine all dataframes
df = pd.concat([df_real, df_sim, df_drawn])

# %%
# print percentage of null values in the cleaned dataframe for each column 
print('Percentage of null values in the cleaned dataframe')
print(df.isnull().sum()/len(df)*100)
# Out:
# Percentage of null values in the cleaned dataframe
# timestamp          0.000000
# label              0.000000
# well               0.000000
# id                 0.000000
# ABER-CKGL         88.912638
# ABER-CKP          83.905354
# ESTADO-DHSV       81.895962
# ESTADO-M1         76.793540
# ESTADO-M2         76.904424
# ESTADO-PXO        76.267346
# ESTADO-SDV-GL     77.665661
# ESTADO-SDV-P      68.250478
# ESTADO-W1         75.272622
# ESTADO-W2         76.114241
# ESTADO-XO         75.793995
# P-ANULAR          66.756226
# P-JUS-BS         100.000000
# P-JUS-CKGL        58.353113
# P-JUS-CKP         71.123209
# P-MON-CKGL        99.596897
# P-MON-CKP          9.244156
# P-MON-SDV-P      100.000000
# P-PDG             10.336197
# PT-P             100.000000
# P-TPT              7.026990
# QBS              100.000000
# QGL               67.924246
# T-JUS-CKP         20.934145
# T-MON-CKP         69.162512
# T-PDG             72.826739
# T-TPT             13.399137
# class              5.259879
# state              5.259879
# Instance           0.000000
# DataType           0.000000
# dtype: float64

# %%
# rename the ids for simulated and handdrawn ids to avoid repetition
df['id'] = np.where(
    df['well'] == 'SIMULATED',
    'SIMULATED - ' + df['id'].astype(str) + " - " + df['label'].astype(str),
    np.where(
        df['well'] == 'DRAWN',
        'DRAWN - ' + df['id'].astype(str) + " - " + df['label'].astype(str),
        df['id']
    )
)

df.head()
# Out:
#              timestamp  label        well              id  ABER-CKGL  \
# 0  2019-09-25 06:11:22      9  WELL-00035  20190925061122        NaN
# 1  2019-09-25 06:11:23      9  WELL-00035  20190925061122        NaN
# 2  2019-09-25 06:11:24      9  WELL-00035  20190925061122        NaN
# 3  2019-09-25 06:11:25      9  WELL-00035  20190925061122        NaN
# 4  2019-09-25 06:11:26      9  WELL-00035  20190925061122        NaN
#
#    ABER-CKP  ESTADO-DHSV  ESTADO-M1  ESTADO-M2  ESTADO-PXO  ...  QBS  \
# 0       NaN          NaN        NaN        NaN         NaN  ...  NaN
# 1       NaN          NaN        NaN        NaN         NaN  ...  NaN
# 2       NaN          NaN        NaN        NaN         NaN  ...  NaN
# 3       NaN          NaN        NaN        NaN         NaN  ...  NaN
# 4       NaN          NaN        NaN        NaN         NaN  ...  NaN
#
#         QGL  T-JUS-CKP  T-MON-CKP  T-PDG  T-TPT  class  state  Instance  \
# 0  1.582202        NaN        NaN    NaN    NaN    NaN    NaN         0
# 1  1.582125        NaN        NaN    NaN    NaN    NaN    NaN         0
# 2  1.582048        NaN        NaN    NaN    NaN    NaN    NaN         0
# 3  1.581971        NaN        NaN    NaN    NaN    NaN    NaN         0
# 4  1.581894        NaN        NaN    NaN    NaN    NaN    NaN         0
#
#    DataType
# 0      Real
# 1      Real
# 2      Real
# 3      Real
# 4      Real
#
# [5 rows x 35 columns]

# %%
# Sort the entire DataFrame by 'id' and 'timestamp' first
df = df.sort_values(['id', 'timestamp'])

# Group by 'id' and apply forward and backward filling within each group except the last 2 columns
# Separate the last two columns
last_two_cols = df.iloc[:, -2:]

# Perform forward and backward fill on all columns except the last two
df_fill = df.iloc[:, :-2].groupby('id').apply(lambda group: group.fillna(method='ffill').fillna(method='bfill'))

# Concatenate the filled columns with the last two columns
df_fill = pd.concat([df_fill.reset_index(drop=True), last_two_cols.reset_index(drop=True)], axis=1)

# Check for any remaining null values and print instances if needed
null_instances = df_fill[df_fill.isnull().any(axis=1)]
# Out:
# /var/folders/0s/y0l9zmw16tv5wcmqxk57mrth0000gn/T/ipykernel_52038/3367687249.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fill = df.iloc[:, :-2].groupby('id').apply(lambda group: group.fillna(method='ffill').fillna(method='bfill'))
# /var/folders/0s/y0l9zmw16tv5wcmqxk57mrth0000gn/T/ipykernel_52038/3367687249.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_fill = df.iloc[:, :-2].groupby('id').apply(lambda group: group.fillna(method='ffill').fillna(method='bfill'))
# /var/folders/0s/y0l9zmw16tv5wcmqxk57mrth0000gn/T/ipykernel_52038/3367687249.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_fill = df.iloc[:, :-2].groupby('id').apply(lambda group: group.fillna(method='ffill').fillna(method='bfill'))

# %%
# print percentage of null values in the cleaned dataframe for each column 
print('Percentage of null values in the cleaned dataframe')
print(df_fill.isnull().sum()/len(df_fill)*100)
# Out:
# Percentage of null values in the cleaned dataframe
# timestamp          0.000000
# label              0.000000
# well               0.000000
# id                 0.000000
# ABER-CKGL         88.741265
# ABER-CKP          83.731365
# ESTADO-DHSV       81.838010
# ESTADO-M1         76.568290
# ESTADO-M2         76.522708
# ESTADO-PXO        76.208673
# ESTADO-SDV-GL     77.505139
# ESTADO-SDV-P      68.183531
# ESTADO-W1         75.211238
# ESTADO-W2         75.735317
# ESTADO-XO         75.735317
# P-ANULAR          66.738525
# P-JUS-BS         100.000000
# P-JUS-CKGL        58.290191
# P-JUS-CKP         71.122121
# P-MON-CKGL        99.596847
# P-MON-CKP          9.179966
# P-MON-SDV-P      100.000000
# P-PDG              9.590798
# PT-P             100.000000
# P-TPT              7.009305
# QBS              100.000000
# QGL               67.837530
# T-JUS-CKP         20.871432
# T-MON-CKP         69.160266
# T-PDG             72.120284
# T-TPT             13.381851
# class              5.259879
# state              5.259879
# dtype: float64

# %%
# Drop columns with more than 50% missing values
df_no_nulls = df_fill.dropna(thresh=len(df_fill) * 0.5, axis=1)

# Initialize a list to store cleaned data
cleaned_data_list = []

# Group by 'id' to process each ID at once
for id_value, id_data in df_no_nulls.groupby('id'):
    # Check if any column is fully null for this ID group
    if id_data.iloc[:, :-2].isnull().any(axis=0).any():
        if any(id_data[col].isnull().all() for col in id_data.columns[:-2]):
            print(f'Dropping id {id_value} due to fully null column(s)')
            # Print percentage of null per column for dropped ids
            print(id_data.isnull().mean() * 100)
            continue  # Skip this id_data if any column is fully null

    # Append the cleaned data for the ID
    cleaned_data_list.append(id_data)

# Concatenate all cleaned data into one DataFrame
no_nulls = pd.concat(cleaned_data_list, ignore_index=True)
# Out:
# Dropping id 20110830235321 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20120601165020 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131104004101 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131208220000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131209000000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131209020000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131209040000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131209060000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131209080000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131209100000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131209120000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131211220015 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131212000148 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131212020000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131212040000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131212060005 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131212080000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131212100000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131214150127 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131214170036 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131214190030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131214210010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131214230010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215010010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215030036 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215050030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215070015 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215090025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215110025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215130036 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215150122 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215170101 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215190132 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20131215210107 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140109000112 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140109020025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140109040025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140109140010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140109160010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140115150010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140115170036 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140118230030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119010020 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119030025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119050010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119070138 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119090112 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119110010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119130010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119150112 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119170015 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119190132 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119210015 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140119230030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120010025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120030132 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120050203 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120070122 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120090010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120110234 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120130224 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120150112 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120170010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120190122 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120210036 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140120230224 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121010056 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121030030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121050010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121070214 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121090056 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121110117 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121130132 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121150025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121170219 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121190234 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121210041 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140121230117 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122010051 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122030046 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122050010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122070127 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122090112 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122110030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122130015 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122150127 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122170112 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122190127 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122210153 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140122230051 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140123010219 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140123030132 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140123050030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140123070010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124050010 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124070020 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124090054 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124110131 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124130041 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124150018 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124170136 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124190008 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124210029 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140124230055 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125010016 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125030033 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125050245 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125070141 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125090025 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125110016 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125130107 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125150112 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125170107 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125190016 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125210046 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140125230059 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126010016 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126030133 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126050141 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126070146 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126090141 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126110241 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126130124 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140126180030 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140212160333 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140301141700 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140325160304 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140403170404 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG        100.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140515083000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140530083203 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140606213810 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140720110102 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140726165720 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140823230118 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140916050300 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140921183228 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140928090056 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140929153332 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20140929210121 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20141005160056 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20141006150121 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20141108012623 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20141117190526 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20141122190000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20150614025713 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20160601130000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT        100.0
# T-JUS-CKP    100.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20160810123500 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG        100.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20170207230000 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT        100.0
# T-JUS-CKP    100.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20170209110022 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20170209160152 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20170209210033 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP    100.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP    100.0
# T-TPT          0.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id 20170210020033 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# ...
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 55 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 56 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 57 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 58 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 59 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 6 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 60 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 61 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 62 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 63 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 64 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 65 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 66 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 67 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 68 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 69 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 7 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 70 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 71 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 72 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 73 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 74 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 75 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 76 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 77 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 78 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 79 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 8 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 80 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 81 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 82 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 83 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 84 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 85 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 86 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 87 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 88 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 89 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 9 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 90 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 91 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 92 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 93 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 94 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 95 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 96 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 97 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 98 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64
# Dropping id SIMULATED - 99 - 6 due to fully null column(s)
# timestamp      0.0
# label          0.0
# well           0.0
# id             0.0
# P-MON-CKP      0.0
# P-PDG          0.0
# P-TPT          0.0
# T-JUS-CKP      0.0
# T-TPT        100.0
# class          0.0
# state          0.0
# Instance       0.0
# DataType       0.0
# dtype: float64

# %%
#get the null values in no_nulls dataframe
print('Percentage of null values in the cleaned dataframe')
print(no_nulls.isnull().sum()/len(no_nulls)*100)
# Out:
# Percentage of null values in the cleaned dataframe
# timestamp    0.0
# label        0.0
# well         0.0
# id           0.0
# P-MON-CKP    0.0
# P-PDG        0.0
# P-TPT        0.0
# T-JUS-CKP    0.0
# T-TPT        0.0
# class        0.0
# state        0.0
# Instance     0.0
# DataType     0.0
# dtype: float64

# %%
# print total ids in the no_nulls dataframe
print(f'Total number of unique ids in the cleaned data: {no_nulls["id"].nunique()}')

# print the number of unique ids in original 
print(f'Total number of unique ids in the original data: {df["id"].nunique()}')
# Out:
# Total number of unique ids in the cleaned data: 1336
# Total number of unique ids in the original data: 2222

# %%
def update_class_values(group):
    # Define the labels that have transition states
    transition_labels = {1, 2, 5, 6, 7, 8, 9}
    # Get the label for this group (assumes all rows in a group have the same label)
    label_value = group['label'].iloc[0]

    # Initialize starting NaNs as 0 (normal operation) until the first non-null value
    first_non_null_index = group['class'].first_valid_index()
    if first_non_null_index is not None:
        # Fill initial NaNs with 0 up to the first non-null value
        group.loc[:first_non_null_index, 'class'] = group.loc[:first_non_null_index, 'class'].fillna(0)
    
    # Now, iterate through the rows to apply the transition and event logic
    for idx in group.index:
        # If class is NaN and we're in the transition state (state=1) and label allows transitions
        if pd.isna(group.loc[idx, 'class']):
            if group.loc[idx, 'state'] == 1 and label_value in transition_labels:
                group.loc[idx, 'class'] = 100 + label_value  # Start transition state
            else:
                # If it's not a transition state, fill with label (event state)
                group.loc[idx, 'class'] = label_value

    return group

# %%
# get list of ids that have null class values
ids_with_null_class = no_nulls[no_nulls['class'].isnull()]['id'].unique()

len(ids_with_null_class)
# Out:
# 0

# %%
# apply the function to update the class values for all ids
no_nulls = no_nulls.groupby('id').apply(update_class_values)

# print percentage of null values in the cleaned dataframe
print('Percentage of null values in the cleaned dataframe')
print(no_nulls.isnull().sum()/len(no_nulls)*100)
# Out:
# /var/folders/0s/y0l9zmw16tv5wcmqxk57mrth0000gn/T/ipykernel_52038/2177637496.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   no_nulls = no_nulls.groupby('id').apply(update_class_values)
# Percentage of null values in the cleaned dataframe
# timestamp    0.0
# label        0.0
# well         0.0
# id           0.0
# P-MON-CKP    0.0
# P-PDG        0.0
# P-TPT        0.0
# T-JUS-CKP    0.0
# T-TPT        0.0
# class        0.0
# state        0.0
# Instance     0.0
# DataType     0.0
# dtype: float64

# %%
#drop state column
no_nulls = no_nulls.drop('state', axis=1)

# change timestamp as datetime
no_nulls['timestamp'] = pd.to_datetime(no_nulls['timestamp'])

#change id as str
no_nulls['id'] = no_nulls['id'].astype(str)

no_nulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 53057829 entries, (20131004225400, 0) to ('SIMULATED - 99 - 9', 53057828)
# Data columns (total 12 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  datetime64[ns]
#  1   label      int64
#  2   well       object
#  3   id         object
#  4   P-MON-CKP  float64
#  5   P-PDG      float64
#  6   P-TPT      float64
#  7   T-JUS-CKP  float64
#  8   T-TPT      float64
#  9   class      float64
#  10  Instance   int64
#  11  DataType   object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(3)
# memory usage: 7.5+ GB

# %%
# save parquet file
no_nulls.to_parquet('../Data/cleaned_data_1.parquet', index=False)
